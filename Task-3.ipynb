# %%
import numpy as np
array1=np.array([10,30,50,70,90])
print(array1)
# Out:
# [10 30 50 70 90]

# %%
import numpy as np
arr=np.array([10,40,67,89])
print(arr[0])
print(arr[3])
# Out:
# 10
# 89

# %%
import numpy as np
arr=np.array([23,56,78,87,69])
print(arr[1:4])
# Out:
# [56 78 87]

# %%
import numpy as np
arr1=np.array([67,54,33])
arr2=np.array([70,65,45])
arr3=np.array([13,23,45])
print(arr1+arr2+arr3)
# Out:
# [150 142 123]

# %%
import numpy as np
a=np.array([2,4,6,8])
print(a*2)
# Out:
# [ 4  8 12 16]

# %%
import numpy as np
arr=np.array([10,20,30,40,50])
print("Sum is:",np.sum(arr))
print("Average value is:",np.mean(arr))
# Out:
# Sum is: 150
# Average value is: 30.0

# %%
import numpy as np
arr=np.array([54,80,99,67])
print(arr)
print("maximum value : ",np.max(arr))
print("minimum value: ",m
